# %%
import numpy as np                # import numpy
import matplotlib.pyplot as plt   # import matplotlib, a python 2d plotting library
import seaborn as sns
import pandas as pd

# %%
#Compile CNN transfer figure
s = np.load('different_cnns.npz')
np.exp(-s['arr_1'])
# Out:
# array([0.09992445, 0.10919723, 0.12229337, 0.13980696])

# %%
np.array([1,2,3,'N/A'])
# Out:
# array(['1', '2', '3', 'N/A'], dtype='<U21')

# %%
#Create dataframe
with np.load('cnn_transfer.npz') as data:
    transfer = data['arr_0']
    R2 = data['arr_1']
    param_distance = data['arr_2']
    etas = data['arr_3']
    
#discard eta=0 column    
transfer = transfer[:,1:]
R2 = R2[:,1:]
etas = etas[1:]

#add diff CNN row
with np.load('different_cnns.npz') as data:
    transfer = np.concatenate([transfer,np.expand_dims(data['arr_0'][1:],0)],axis=0)
    R2 = np.concatenate([R2,np.expand_dims(np.exp(-data['arr_1'])[1:],0)],axis=0)
    param_distance = np.concatenate([param_distance,np.array([-1])])

param_distance
#sns.lineplot(x=param_distance, y=transfer[:,1])
transfer = transfer*100

n,m = R2.shape
data = np.zeros([n*m,4])
for i in range(n):
    for j in range(m):
        data[j+i*m,0] = transfer[i,j]
        data[j+i*m,1] = R2[i,j]
        data[j+i*m,2] = etas[j]
        data[j+i*m,3] = param_distance[i]

data = pd.DataFrame(data, columns = ['Transfer Rate (%)','R2', r'$\epsilon$', 'param_dist'],)

# %%
sns.set_theme()
fig, ax = plt.subplots(1,2, figsize=(15,5))
sns.lineplot(ax=ax[0], data=data[data.param_dist != -1], x='param_dist', y='Transfer Rate (%)', hue=r'$\epsilon$', palette='Blues_d')
ax[0].set_ylim(0,100)
ax[0].set_xlabel('Parameter Distance')

sns.lineplot(ax=ax[1], data=data[data.param_dist != -1], x='param_dist', y='R2', hue=r'$\epsilon$', palette='Blues_d')
ax[1].set_ylim(0.8,1)
ax[1].set_xlabel('Parameter Distance')
ax[1].set_ylabel(r'$R^2$')
# Out:
# Text(0, 0.5, '$R^2$')

# %%
fig.savefig('param_dist_comparison.jpg', bbox_inches = 'tight', pad_inches = 0, format='jpg', dpi=600)

# %%
#Next Plot
ndata = data[data.param_dist != 1500]
ndata = ndata[ndata.param_dist != 2500]
ndata.loc[ndata['param_dist']!=-1, 'param_dist'] = 0.00
ndata.loc[ndata['param_dist']==-1, 'param_dist'] = 0.05
ndata = ndata.rename(columns={'param_dist': r'$\lambda$'})

fig, ax = plt.subplots()
sns.lineplot(ax = ax, data=ndata, x=r'$\epsilon$', y='Transfer Rate (%)', hue=r'$\lambda$', palette='Blues_d')
plt.ylim(0,100)
plt.xlabel(r'$\epsilon$')
# Out:
# Text(0.5, 0, '$\\epsilon$')

# %%
fig.savefig('CNN_transfer_rates.jpg', bbox_inches = 'tight', pad_inches = 0, format='jpg', dpi=600)

# %%
#Bar Graphs for PGD (no adversarial training)
data = np.load('PGD_table_lambda0.0.npy')[:,1:]
labels = np.expand_dims(np.array(['{}_PGD'.format(x) for x in [0.00, 0.05, 0.10, 0.15]]), axis=1)
data = np.concatenate([np.tile(0.00, (4,1)), labels, data],axis=1)

datan = np.load('PGD_table_lambda0.05.npy')[:,1:]
labels = np.expand_dims(np.array(['{}_PGD'.format(x) for x in [0.00, 0.05, 0.10, 0.15]]), axis=1)
datan = np.concatenate([np.tile(0.05, (4,1)), labels, datan],axis=1)
data = np.concatenate([data,datan], axis=0)

datan = np.load('results_table_lambda0.0.npy')[:,1:]
labels = np.expand_dims(np.array(['{}_FGSM'.format(x) for x in [0.00, 0.05, 0.10, 0.15]]), axis=1)
datan = np.concatenate([np.tile(0.00, (4,1)), labels, datan],axis=1)
data = np.concatenate([data,datan], axis=0)

datan = np.load('results_table_lambda0.05.npy')[:,1:]
labels = np.expand_dims(np.array(['{}_FGSM'.format(x) for x in [0.00, 0.05, 0.10, 0.15]]), axis=1)
datan = np.concatenate([np.tile(0.05, (4,1)), labels, datan],axis=1)
data = np.concatenate([data,datan], axis=0)


data = pd.DataFrame(data, columns=[r'$\lambda$', 'Attack', 'dual_correct', '1_correct', '2_correct', 'dual_incorrect', 'det_correct'])
measures = ['dual_correct', '1_correct', '2_correct', 'dual_incorrect', 'det_correct']
for i in measures:
    data[measures] = data[measures].astype(float)


measures.append('either_correct')

data['either_correct'] = data['1_correct'] + data['2_correct']
data = data.drop(['1_correct','2_correct'], axis=1)

data = data.melt(id_vars = [r'$\lambda$', 'Attack'], var_name='measure', value_name='percent')


order = ['dual_correct','either_correct','dual_incorrect','det_correct']
#sns.barplot(x='measure', y='percent', hue=r'$\lambda$', data=data[data.Attack == '0.0_PGD'], order=order, palette='Blues_d')

fig, ax = plt.subplots(2,2, figsize=(15,8))
titles = [['Natural Samples', r'PGD ($\epsilon=0.05)$', r'PGD ($\epsilon=0.10)$', r'PGD ($\epsilon=0.15)$'],
         ['0.0_PGD', '0.05_PGD', '0.1_PGD', '0.15_PGD']]

for i in range(4):
    sns.barplot(ax=ax[int(i/2),i%2], x='measure', y='percent', hue=r'$\lambda$', data=data[data.Attack == titles[1][i]], order=order, palette='Blues_d')
    ax[int(i/2),i%2].set_title(titles[0][i])
    ax[int(i/2),i%2].set_xlabel(None)
    ax[int(i/2),i%2].set_ylim([0,100])

# %%
fig.savefig('bar_plot_PGD.jpg', bbox_inches = 'tight', pad_inches = 0, format='jpg', dpi=600)

# %%
#Bar Graphs for PGD (adversarial training)
data = np.load('PGD_table_lambda0.0_adv_trained.npy')[:,1:]
labels = np.expand_dims(np.array(['{}_PGD'.format(x) for x in [0.00, 0.05, 0.10, 0.15]]), axis=1)
data = np.concatenate([np.tile(0.00, (4,1)), labels, data],axis=1)

datan = np.load('PGD_table_lambda0.05_adv_trained.npy')[:,1:]
labels = np.expand_dims(np.array(['{}_PGD'.format(x) for x in [0.00, 0.05, 0.10, 0.15]]), axis=1)
datan = np.concatenate([np.tile(0.05, (4,1)), labels, datan],axis=1)
data = np.concatenate([data,datan], axis=0)

datan = np.load('results_table_lambda0.0_adv_trained.npy')[:,1:]
labels = np.expand_dims(np.array(['{}_FGSM'.format(x) for x in [0.00, 0.05, 0.10, 0.15]]), axis=1)
datan = np.concatenate([np.tile(0.00, (4,1)), labels, datan],axis=1)
data = np.concatenate([data,datan], axis=0)

datan = np.load('results_table_lambda0.05_adv_trained.npy')[:,1:]
labels = np.expand_dims(np.array(['{}_FGSM'.format(x) for x in [0.00, 0.05, 0.10, 0.15]]), axis=1)
datan = np.concatenate([np.tile(0.05, (4,1)), labels, datan],axis=1)
data = np.concatenate([data,datan], axis=0)


data = pd.DataFrame(data, columns=[r'$\lambda$', 'Attack', 'dual_correct', '1_correct', '2_correct', 'dual_incorrect', 'det_correct'])
measures = ['dual_correct', '1_correct', '2_correct', 'dual_incorrect', 'det_correct']
for i in measures:
    data[measures] = data[measures].astype(float)


measures.append('either_correct')

data['either_correct'] = data['1_correct'] + data['2_correct']
data = data.drop(['1_correct','2_correct'], axis=1)

data = data.melt(id_vars = [r'$\lambda$', 'Attack'], var_name='measure', value_name='percent')


order = ['dual_correct','either_correct','dual_incorrect','det_correct']
#sns.barplot(x='measure', y='percent', hue=r'$\lambda$', data=data[data.Attack == '0.0_PGD'], order=order, palette='Blues_d')

fig, ax = plt.subplots(2,2, figsize=(15,8))
titles = [['Natural Samples', r'PGD ($\epsilon=0.05)$', r'PGD ($\epsilon=0.10)$', r'PGD ($\epsilon=0.15)$'],
         ['0.0_PGD', '0.05_PGD', '0.1_PGD', '0.15_PGD']]

for i in range(4):
    sns.barplot(ax=ax[int(i/2),i%2], x='measure', y='percent', hue=r'$\lambda$', data=data[data.Attack == titles[1][i]], order=order, palette='Blues_d')
    ax[int(i/2),i%2].set_title(titles[0][i])
    ax[int(i/2),i%2].set_xlabel(None)
    ax[int(i/2),i%2].set_ylim([0,100])

# %%
fig.savefig('bar_plot_PGD_adv.jpg', bbox_inches = 'tight', pad_inches = 0, format='jpg', dpi=600)

# %%
fig, ax = plt.subplots(2,2, figsize=(15,8))
titles = [['Natural Samples', r'FGSM ($\epsilon=0.05)$', r'FGSM ($\epsilon=0.10)$', r'FGSM ($\epsilon=0.15)$'],
         ['0.0_FGSM', '0.05_FGSM', '0.1_FGSM', '0.15_FGSM']]

for i in range(4):
    sns.barplot(ax=ax[int(i/2),i%2], x='measure', y='percent', hue=r'$\lambda$', data=data[data.Attack == titles[1][i]], order=order, palette='Blues_d')
    ax[int(i/2),i%2].set_title(titles[0][i])
    ax[int(i/2),i%2].set_xlabel(None)
    ax[int(i/2),i%2].set_ylim([0,100])

# %%
fig.savefig('bar_plot_FGSM_adv.jpg', bbox_inches = 'tight', pad_inches = 0, format='jpg', dpi=600)
